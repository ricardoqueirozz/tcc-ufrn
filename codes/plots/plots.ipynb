# %%
# loading in modules
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as ss

# Read the CSV file
PIR = pd.read_csv("/home/ricardo/Repositories/tcc/plots/results_intel-256_NrV2X_SimPerScriptCampaign_Campaign_1_Fase_2_dataRateBe/data/PIR-V2X-CDF.csv")
PRR = pd.read_csv("/home/ricardo/Repositories/tcc/plots/results_intel-256_NrV2X_SimPerScriptCampaign_Campaign_1_Fase_2_dataRateBe/data/PRR-V2X-CDF.csv")
Tput = pd.read_csv("/home/ricardo/Repositories/tcc/plots/results_intel-256_NrV2X_SimPerScriptCampaign_Campaign_1_Fase_2_dataRateBe/data/Tput-V2X-CDF.csv")



data = np.loadtxt('Filename.txt')

# Choose how many bins you want here
num_bins = 20

# Use the histogram function to bin the data
counts, bin_edges = np.histogram(data, bins=num_bins, normed=True)

# Now find the cdf
cdf = np.cumsum(counts)

# And finally plot the cdf
plt.plot(bin_edges[1:], cdf)

plt.show()
# Out:
# Text(0, 0.5, 'CDF')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = "Times New Roman"
from itertools import cycle

# %% [markdown]
# # Paths

# %%
path = '/home/ricardo/Repositories/tcc/plots/'

Cp1 = 'results_intel-256_NrV2X_SimPerScriptCampaign_Campaign_1_Fase_2_dataRateBe/data'
Cp2 = 'results_intel-256_NrV2X_SimPerScriptCampaign_Campaign_2_Fase_2_dataRateBe/data'
Cp3 = 'results_intel-256_NrV2X_SimPerScriptCampaign_Campaign_3_Fase_2_dataRateBe/data'

# %% [markdown]
# ## CP1

# %%
# Plot fixed parameters
linestyleA= ['-','-','-','-','-']# '-.', ':'))
linestyleB= ['--','--','-','--','-']# '-.', ':'))
#colors = cycle(('b', 'g', 'r', 'c', 'm', 'y', 'k'))
#colorsA = ['tab:blue', 'tab:orange', 'tab:blue', 'tab:orange']
colorsA = ['blue', 'orange', 'green', 'red','purple','brown','pink']
colorsB = ['green', 'purple']
markersA = ['o','v', 'X', '*', 'h', '^', '*', '>', 's', 'H', 'D', 'd']
linewidth = 2
fontSize = 25
fontSizeLeg = 20
figsize=(10,6)

# %%
#### PIR ####

dfPir = pd.read_csv(path+Cp1+'/PIR-V2X-CDF.csv',delimiter=',')
dfPir=dfPir.drop(columns= 'Unnamed: 0')

#### PRR ####

dfPrr = pd.read_csv(path+Cp1+'/PRR-V2X-CDF.csv',delimiter=',')
dfPrr=dfPrr.drop(columns= 'Unnamed: 0')

#### tput ####

dfTput = pd.read_csv(path+Cp1+'/Tput-V2X-CDF.csv',delimiter=',')
dfTput=dfTput.drop(columns= 'Unnamed: 0')

# %%
dfPirCp1 = pd.DataFrame()
dfPirCp1 = pd.concat([dfPirCp1,
                        dfPir['V2X_TCC_Campaign_1_Fase_2: mcs 10, dataRateBe 24'],
                        dfPir['V2X_TCC_Campaign_1_Fase_2: mcs 11, dataRateBe 24'],
                        dfPir['V2X_TCC_Campaign_1_Fase_2: mcs 12, dataRateBe 24'],
                        dfPir['V2X_TCC_Campaign_1_Fase_2: mcs 13, dataRateBe 24'],
                        dfPir['V2X_TCC_Campaign_1_Fase_2: mcs 14, dataRateBe 24'],
                      ],axis=1)

dfPrrCp1 = pd.DataFrame()
dfPrrCp1 = pd.concat([dfPrrCp1,
                        dfPrr['V2X_TCC_Campaign_1_Fase_2: mcs 10, dataRateBe 24'],
                        dfPrr['V2X_TCC_Campaign_1_Fase_2: mcs 11, dataRateBe 24'],
                        dfPrr['V2X_TCC_Campaign_1_Fase_2: mcs 12, dataRateBe 24'],
                        dfPrr['V2X_TCC_Campaign_1_Fase_2: mcs 13, dataRateBe 24'],
                        dfPrr['V2X_TCC_Campaign_1_Fase_2: mcs 14, dataRateBe 24'],
                      ],axis=1)

dfTputCp1 = pd.DataFrame()
dfTputCp1 = pd.concat([dfTputCp1,
                        dfTput['V2X_TCC_Campaign_1_Fase_2: mcs 10, dataRateBe 24'],
                        dfTput['V2X_TCC_Campaign_1_Fase_2: mcs 11, dataRateBe 24'],
                        dfTput['V2X_TCC_Campaign_1_Fase_2: mcs 12, dataRateBe 24'],
                        dfTput['V2X_TCC_Campaign_1_Fase_2: mcs 13, dataRateBe 24'],
                        dfTput['V2X_TCC_Campaign_1_Fase_2: mcs 14, dataRateBe 24'],
                      ],axis=1)

# %%
# PIR
legendCdf= [
            'MCS 10',
            'MCS 11',
            'MCS 12',
            'MCS 13',
            'MCS 14',
           ]
labelAcdf = cycle(legendCdf)
linestyle = cycle((linestyleA))
markers = cycle(markersA)
colors = cycle(colorsA)
dfmetric = dfPirCp1

plt.figure(figsize=figsize)
plt.rc('font', size=fontSize)          # controls default text sizes
labelcdf = next(labelAcdf)
linestyle_on=next(linestyle)
color=next(colors)
markers_on = next(markers)
for i in range (dfmetric.shape[1]):
    resyData, resxData =np.histogram(dfmetric.iloc[:,i].dropna(),density=True,bins=1000)
    cdf = np.cumsum(resyData*np.diff(resxData))
    plt.plot(resxData[1:], cdf,label=labelcdf,ls=linestyle_on,color=color,linewidth=linewidth,marker=markers_on,markevery=50)
    labelcdf = next(labelAcdf)
    linestyle_on=next(linestyle)
    color=next(colors)
    markers_on = next(markers)
plt.xlabel("PIR Médio (ms)")
plt.ylabel("CDF")
plt.grid()
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(fontsize=fontSizeLeg)
plt.tight_layout()
plt.xlim([95, 450])

# PRR
legendCdf= [
            'MCS 10',
            'MCS 11',
            'MCS 12',
            'MCS 13',
            'MCS 14',
           ]
labelAcdf = cycle(legendCdf)
linestyle = cycle((linestyleA))
markers = cycle(markersA)
colors = cycle(colorsA)
dfmetric = dfPrrCp1

plt.figure(figsize=figsize)
plt.rc('font', size=fontSize)          # controls default text sizes
labelcdf = next(labelAcdf)
linestyle_on=next(linestyle)
color=next(colors)
markers_on = next(markers)
for i in range (dfmetric.shape[1]):
    resyData, resxData =np.histogram(dfmetric.iloc[:,i].dropna(),density=True,bins=1000)
    cdf = np.cumsum(resyData*np.diff(resxData))
    plt.plot(resxData[1:], cdf,label=labelcdf,ls=linestyle_on,color=color,linewidth=linewidth,marker=markers_on,markevery=50)
    labelcdf = next(labelAcdf)
    linestyle_on=next(linestyle)
    color=next(colors)
    markers_on = next(markers)
plt.xlabel("PRR Médio")
plt.ylabel("CDF")
plt.grid()
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(fontsize=fontSizeLeg)
plt.tight_layout()
plt.xlim([0.4, 1])

# tput
legendCdf= [
            'MCS 10',
            'MCS 11',
            'MCS 12',
            'MCS 13',
            'MCS 14',
           ]
labelAcdf = cycle(legendCdf)
linestyle = cycle((linestyleB))
markers = cycle(markersA)
colors = cycle(colorsA)
dfmetric = dfTputCp1

plt.figure(figsize=figsize)
plt.rc('font', size=fontSize)          # controls default text sizes
labelcdf = next(labelAcdf)
linestyle_on=next(linestyle)
color=next(colors)
markers_on = next(markers)
for i in range (dfmetric.shape[1]):
    resyData, resxData =np.histogram(dfmetric.iloc[:,i].dropna(),density=True,bins=1000)
    cdf = np.cumsum(resyData*np.diff(resxData))
    plt.plot(resxData[1:], cdf,label=labelcdf,ls=linestyle_on,color=color,linewidth=linewidth,marker=markers_on,markevery=50)
    labelcdf = next(labelAcdf)
    linestyle_on=next(linestyle)
    color=next(colors)
    markers_on = next(markers)
plt.xlabel("Throughput Médio (kbps)", fontname='Times New Roman')
plt.ylabel("CDF")
plt.grid()
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(fontsize=fontSizeLeg)
plt.tight_layout()
plt.xlim([0, 24])
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# (0.0, 24.0)

# %% [markdown]
# ## CP2

# %%
# Plot fixed parameters
linestyleA= ['-','-','-','-']# '-.', ':'))
linestyleB= ['-','--','-','--','-','--']
linestyleC= ['-','--','-','-']# '-.', ':'))
#colors = cycle(('b', 'g', 'r', 'c', 'm', 'y', 'k'))
#colorsA = ['tab:blue', 'tab:orange', 'tab:blue', 'tab:orange']
colorsA = ['blue', 'orange', 'green', 'red','purple','brown','pink']
colorsB = ['blue', 'blue', 'green', 'green','orange','orange','red','red']
colorsC = ['blue', 'orange', 'orange', 'green']
markersA = ['o','^', 'X', '*', 'h', '^', '*', '>', 's', 'H', 'D', 'd']
markersB = ['o','^', 'o', '^', 'o', '^']
linewidth = 2
fontSize = 25
fontSizeLeg = 15
figsize=(10,6)

# %%
#### PIR ####

dfPir2 = pd.read_csv(path+Cp2+'/PIR-V2X-CDF.csv',delimiter=',')
dfPir2=dfPir2.drop(columns= 'Unnamed: 0')

#### PRR ####

dfPrr2 = pd.read_csv(path+Cp2+'/PRR-V2X-CDF.csv',delimiter=',')
dfPrr2=dfPrr2.drop(columns= 'Unnamed: 0')

#### tput ####

dfTput2 = pd.read_csv(path+Cp2+'/Tput-V2X-CDF.csv',delimiter=',')
dfTput2=dfTput2.drop(columns= 'Unnamed: 0')

# %%
dfPirCp2 = pd.DataFrame()
dfPirCp2 = pd.concat([dfPirCp2,
                        dfPir2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 78, mcs 13, dataRateBe 24'],
                        dfPir2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 156, mcs 13, dataRateBe 24'],
                        dfPir2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 156, mcs 14, dataRateBe 24'],
                        dfPir2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 312, mcs 14, dataRateBe 24'],
                      ],axis=1)

dfPrrCp2 = pd.DataFrame()
dfPrrCp2 = pd.concat([dfPrrCp2,
                        dfPrr2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 78, mcs 12, dataRateBe 24'],
                        dfPrr2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 156, mcs 12, dataRateBe 24'],
                        dfPrr2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 312, mcs 14, dataRateBe 24'],
                      ],axis=1)

dfTputCp2 = pd.DataFrame()
dfTputCp2 = pd.concat([dfTputCp2,
                        dfTput2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 78, mcs 12, dataRateBe 24'],
                        dfTput2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 78, mcs 14, dataRateBe 24'],
                        dfTput2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 156, mcs 12, dataRateBe 24'],
                        dfTput2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 156, mcs 14, dataRateBe 24'],
                        dfTput2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 312, mcs 12, dataRateBe 24'],
                        dfTput2['V2X_TCC_Campaign_2_Fase_2: interVehicleDist 312, mcs 14, dataRateBe 24'],
                      ],axis=1)

# %%
# PIR
legendCdf= [
            'MCS 13, 78 m',
            'MCS 13, 156 m',
            'MCS 14, 156 m',
            'MCS 14, 312 m',
           ]
labelAcdf = cycle(legendCdf)
linestyle = cycle((linestyleC))
markers = cycle(markersA)
colors = cycle(colorsC)
dfmetric = dfPirCp2

plt.figure(figsize=figsize)
plt.rc('font', size=fontSize)          # controls default text sizes
labelcdf = next(labelAcdf)
linestyle_on=next(linestyle)
color=next(colors)
markers_on = next(markers)
for i in range (dfmetric.shape[1]):
    resyData, resxData =np.histogram(dfmetric.iloc[:,i].dropna(),density=True,bins=1000)
    cdf = np.cumsum(resyData*np.diff(resxData))
    plt.plot(resxData[1:], cdf,label=labelcdf,ls=linestyle_on,color=color,linewidth=linewidth,marker=markers_on,markevery=30)
    labelcdf = next(labelAcdf)
    linestyle_on=next(linestyle)
    color=next(colors)
    markers_on = next(markers)
plt.xlabel("PIR Médio (ms)")
plt.ylabel("CDF")
plt.grid()
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(fontsize=fontSizeLeg)
plt.tight_layout()
plt.xlim([95, 450])

# PRR
legendCdf= [
            'MCS 12, 78 m',
            'MCS 12, 156 m',
            'MCS 14, 312 m',
           ]
labelAcdf = cycle(legendCdf)
linestyle = cycle((linestyleA))
markers = cycle(markersA)
colors = cycle(colorsA)
dfmetric = dfPrrCp2

plt.figure(figsize=figsize)
plt.rc('font', size=fontSize)          # controls default text sizes
labelcdf = next(labelAcdf)
linestyle_on=next(linestyle)
color=next(colors)
markers_on = next(markers)
for i in range (dfmetric.shape[1]):
    resyData, resxData =np.histogram(dfmetric.iloc[:,i].dropna(),density=True,bins=1000)
    cdf = np.cumsum(resyData*np.diff(resxData))
    plt.plot(resxData[1:], cdf,label=labelcdf,ls=linestyle_on,color=color,linewidth=linewidth,marker=markers_on,markevery=30)
    labelcdf = next(labelAcdf)
    linestyle_on=next(linestyle)
    color=next(colors)
    markers_on = next(markers)
plt.xlabel("PRR Médio")
plt.ylabel("CDF")
plt.grid()
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(fontsize=fontSizeLeg)
plt.tight_layout()
plt.xlim([0.5, 1])

# tput
legendCdf= [
            'MCS 12, 78 m',
            'MCS 14, 78 m',
            'MCS 12, 156 m',
            'MCS 14, 156 m',
            'MCS 12, 312 m',
            'MCS 14, 312 m',
           ]
labelAcdf = cycle(legendCdf)
linestyle = cycle((linestyleB))
markers = cycle(markersB)
colors = cycle(colorsB)
dfmetric = dfTputCp2

plt.figure(figsize=figsize)
plt.rc('font', size=fontSize)          # controls default text sizes
labelcdf = next(labelAcdf)
linestyle_on=next(linestyle)
color=next(colors)
markers_on = next(markers)
for i in range (dfmetric.shape[1]):
    resyData, resxData =np.histogram(dfmetric.iloc[:,i].dropna(),density=True,bins=1000)
    cdf = np.cumsum(resyData*np.diff(resxData))
    plt.plot(resxData[1:], cdf,label=labelcdf,ls=linestyle_on,color=color,linewidth=linewidth,marker=markers_on,markevery=50)
    labelcdf = next(labelAcdf)
    linestyle_on=next(linestyle)
    color=next(colors)
    markers_on = next(markers)
plt.xlabel("Throughput Médio (kbps)")
plt.ylabel("CDF")
plt.grid()
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(fontsize=fontSizeLeg)
plt.tight_layout()
plt.xlim([0, 24])
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# (0.0, 24.0)

# %% [markdown]
# ## CP3

# %%
# Plot fixed parameters
linestyleA= ['-','-','-','-','-']# '-.', ':'))
linestyleB= ['-','--','-','--','-','--']
linestyleC= ['-','-','--','-','-']# '-.', ':'))
#colors = cycle(('b', 'g', 'r', 'c', 'm', 'y', 'k'))
#colorsA = ['tab:blue', 'tab:orange', 'tab:blue', 'tab:orange']
colorsA = ['blue', 'orange', 'green', 'red','purple','brown','pink']
colorsB = ['blue', 'orange', 'orange', 'green', 'red']
colorsC = ['blue', 'blue', 'orange', 'orange', 'green', 'green', 'red', 'red']
markersA = ['o','^', 'X', '*', 'h', '^', '*', '>', 's', 'H', 'D', 'd']
markersB = ['o','^', 'o', '^', 'o', '^', 'o', '^']
linewidth = 2
fontSize = 25
fontSizeLeg = 15
figsize=(10,6)

# %%
#### PIR ####

dfPir3 = pd.read_csv(path+Cp3+'/PIR-V2X-CDF.csv',delimiter=',')
dfPir3=dfPir3.drop(columns= 'Unnamed: 0')

#### PRR ####

dfPrr3 = pd.read_csv(path+Cp3+'/PRR-V2X-CDF.csv',delimiter=',')
dfPrr3=dfPrr3.drop(columns= 'Unnamed: 0')

#### tput ####

dfTput3 = pd.read_csv(path+Cp3+'/Tput-V2X-CDF.csv',delimiter=',')
dfTput3=dfTput3.drop(columns= 'Unnamed: 0')

# %%
dfPirCp3 = pd.DataFrame()
dfPirCp3 = pd.concat([dfPirCp3,
                        dfPir3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 39, numVehiclesPerLane 20, mcs 13, dataRateBe 24'],
                        dfPir3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 39, numVehiclesPerLane 80, mcs 13, dataRateBe 24'],
                        dfPir3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 39, numVehiclesPerLane 80, mcs 14, dataRateBe 24'],
                        dfPir3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 78, numVehiclesPerLane 20, mcs 13, dataRateBe 24'],
                        dfPir3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 78, numVehiclesPerLane 80, mcs 13, dataRateBe 24'],
                      ],axis=1)

dfPrrCp3 = pd.DataFrame()
dfPrrCp3 = pd.concat([dfPrrCp3,
                        dfPrr3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 39, numVehiclesPerLane 20, mcs 12, dataRateBe 24'],
                        dfPrr3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 39, numVehiclesPerLane 80, mcs 12, dataRateBe 24'],
                        dfPrr3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 78, numVehiclesPerLane 20, mcs 12, dataRateBe 24'],
                        dfPrr3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 78, numVehiclesPerLane 80, mcs 12, dataRateBe 24'],
                      ],axis=1)

dfTputCp3 = pd.DataFrame()
dfTputCp3 = pd.concat([dfTputCp3,
                        dfTput3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 39, numVehiclesPerLane 20, mcs 12, dataRateBe 24'],
                        dfTput3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 39, numVehiclesPerLane 20, mcs 14, dataRateBe 24'],
                        dfTput3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 39, numVehiclesPerLane 80, mcs 12, dataRateBe 24'],
                        dfTput3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 39, numVehiclesPerLane 80, mcs 14, dataRateBe 24'],
                        dfTput3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 78, numVehiclesPerLane 20, mcs 12, dataRateBe 24'],
                        dfTput3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 78, numVehiclesPerLane 20, mcs 14, dataRateBe 24'],
                        dfTput3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 78, numVehiclesPerLane 80, mcs 12, dataRateBe 24'],
                        dfTput3['V2X_TCC_Campaign_3_Fase_2: interVehicleDist 78, numVehiclesPerLane 80, mcs 14, dataRateBe 24'],
                      ],axis=1)

# %%
# PIR
legendCdf= [
            'MCS 13, 39 m, 20 Veículos',
            'MCS 13, 39 m, 80 Veículos',
            'MCS 14, 39 m, 80 Veículos',
            'MCS 13, 78 m, 20 Veículos',
            'MCS 13, 78 m, 80 Veículos',
           ]
labelAcdf = cycle(legendCdf)
linestyle = cycle((linestyleC))
markers = cycle(markersA)
colors = cycle(colorsB)
dfmetric = dfPirCp3

plt.figure(figsize=figsize)
plt.rc('font', size=fontSize)          # controls default text sizes
labelcdf = next(labelAcdf)
linestyle_on=next(linestyle)
color=next(colors)
markers_on = next(markers)
for i in range (dfmetric.shape[1]):
    resyData, resxData =np.histogram(dfmetric.iloc[:,i].dropna(),density=True,bins=1000)
    cdf = np.cumsum(resyData*np.diff(resxData))
    plt.plot(resxData[1:], cdf,label=labelcdf,ls=linestyle_on,color=color,linewidth=linewidth,marker=markers_on,markevery=30)
    labelcdf = next(labelAcdf)
    linestyle_on=next(linestyle)
    color=next(colors)
    markers_on = next(markers)
plt.xlabel("PIR Médio (ms)")
plt.ylabel("CDF")
plt.grid()
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(fontsize=fontSizeLeg)
plt.tight_layout()
plt.xlim([95, 450])

# PRR
legendCdf= [
            'MCS 12, 39 m, 20 Veículos',
            'MCS 12, 39 m, 80 Veículos',
            'MCS 12, 78 m, 20 Veículos',
            'MCS 12, 78 m, 80 Veículos',
           ]
labelAcdf = cycle(legendCdf)
linestyle = cycle((linestyleA))
markers = cycle(markersA)
colors = cycle(colorsA)
dfmetric = dfPrrCp3

plt.figure(figsize=figsize)
plt.rc('font', size=fontSize)          # controls default text sizes
labelcdf = next(labelAcdf)
linestyle_on=next(linestyle)
color=next(colors)
markers_on = next(markers)
for i in range (dfmetric.shape[1]):
    resyData, resxData =np.histogram(dfmetric.iloc[:,i].dropna(),density=True,bins=1000)
    cdf = np.cumsum(resyData*np.diff(resxData))
    plt.plot(resxData[1:], cdf,label=labelcdf,ls=linestyle_on,color=color,linewidth=linewidth,marker=markers_on,markevery=50)
    labelcdf = next(labelAcdf)
    linestyle_on=next(linestyle)
    color=next(colors)
    markers_on = next(markers)
plt.xlabel("PRR Médio")
plt.ylabel("CDF")
plt.grid()
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(fontsize=fontSizeLeg)
plt.tight_layout()
plt.xlim([0.4, 1])

# tput
legendCdf= [
            'MCS 12, 39 m, 20 Veículos',
            'MCS 14, 39 m, 20 Veículos',
            'MCS 12, 39 m, 80 Veículos',
            'MCS 14, 39 m, 80 Veículos',
            'MCS 12, 78 m, 20 Veículos',
            'MCS 14, 78 m, 20 Veículos',
            'MCS 12, 78 m, 80 Veículos',
            'MCS 14, 78 m, 80 Veículos',
           ]
labelAcdf = cycle(legendCdf)
linestyle = cycle((linestyleB))
markers = cycle(markersB)
colors = cycle(colorsC)
dfmetric = dfTputCp3

plt.figure(figsize=figsize)
plt.rc('font', size=fontSize)          # controls default text sizes
labelcdf = next(labelAcdf)
linestyle_on=next(linestyle)
color=next(colors)
markers_on = next(markers)
for i in range (dfmetric.shape[1]):
    resyData, resxData =np.histogram(dfmetric.iloc[:,i].dropna(),density=True,bins=1000)
    cdf = np.cumsum(resyData*np.diff(resxData))
    plt.plot(resxData[1:], cdf,label=labelcdf,ls=linestyle_on,color=color,linewidth=linewidth,marker=markers_on,markevery=50)
    labelcdf = next(labelAcdf)
    linestyle_on=next(linestyle)
    color=next(colors)
    markers_on = next(markers)
plt.xlabel("Throughput Médio (kbps)")
plt.ylabel("CDF")
plt.grid()
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(fontsize=fontSizeLeg)
plt.tight_layout()
plt.xlim([0, 48])
# Out:
# (0.0, 48.0)
